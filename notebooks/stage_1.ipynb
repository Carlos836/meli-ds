# %% [markdown]
# # Stage 1: Análisis Exploratorio de Datos
#
# Este notebook corresponde al primer stage del reto técnico para Mercado Libre.
#
# ## Objetivos:
# - Cargar y explorar los datos
# - Realizar análisis exploratorio de datos (EDA)
# - Identificar patrones y características relevantes
# - Preparar los datos para el siguiente stage

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Configuración de visualización
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print("Librerías importadas correctamente")

# %% [markdown]
# ## 1. Carga de Datos

# %%
# Cargar datos desde la carpeta data/raw
# TODO: Reemplazar con la ruta real de los datos
data_path = '../data/raw/'

# Ejemplo de carga de datos (ajustar según el formato real)
# df = pd.read_csv(data_path + 'dataset.csv')
# df = pd.read_parquet(data_path + 'dataset.parquet')

print("Datos cargados correctamente")
